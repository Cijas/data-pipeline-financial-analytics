# %%
# Jupyter Notebook - Financial Data Exploration

Este notebook é para exploração e validação dos dados do pipeline.

## Como usar:

1. Instale jupyter: `pip install jupyter`
2. Execute: `jupyter notebook exploration.ipynb`
3. Explore os dados gerados pelo pipeline

## Seções:

- **Imports & Setup** - Carrega dados processados
- **Raw Data Analysis** - Análise de dados brutos
- **Distributions** - Gráficos de distribuição
- **Customer Insights** - Análise por cliente
- **Category Analysis** - Análise por categoria
- **Quality Checks** - Validação de qualidade

Para criar as células, execute o pipeline primeiro:
```bash
cd src
python pipeline.py
```

Depois abra este notebook e execute as células.
